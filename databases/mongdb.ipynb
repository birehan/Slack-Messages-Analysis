# %%
from pymongo import MongoClient
import pprint

import os, sys
# Add parent directory to path to import modules from src
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0, rpath)

from src.loader import SlackDataLoader
import src.utils as utils
import json
import pandas as pd

data_loader = SlackDataLoader("../data")

# %%
class DBWithSchema:
    def __init__(self) -> None:
        self.client = MongoClient("mongodb://localhost:27017/")
        self.db = self.client["SlackDb"]

        self.user_validator = {
            "$jsonSchema": {
                "bsonType": "object",
                "required": ["user_id", "real_name"],
                "properties": {
                    "user_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "real_name": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    }
                }
            }
        }

        self.channel_validator = {
            "$jsonSchema": {
                "bsonType": "object",
                "required": ["channel_id", "name"],
                "properties": {
                    "channel_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "name": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    }
                }
            }
        }

        self.message_validator = {
            "$jsonSchema": {
                "bsonType": "object",
                "required": ["ts", "msg_id", "text", "user_id", "channel_id", "mentions", "reactions", "replies"],
                "properties": {
                    "ts": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },

                    "msg_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "text": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "user_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "channel_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "mentions": {
                        'bsonType': ['array', 'null'],

                        "items": {
                            "bsonType": "string"
                        },
                        "description": "must be an array of strings"
                    },
                    "reactions": {
                        'bsonType': ['array', 'null'],

                        "items": {
                            "bsonType": "object",
                            "required": ["name", "users", "count"],
                            "properties": {
                                "name": {
                                    "bsonType": "string",
                                    "description": "must be a string and is required"
                                },
                                "users": {
                                    "bsonType": "array",
                                    "items": {
                                        "bsonType": "string"
                                    },
                                    "description": "must be an array of strings"
                                },
                                "count": {
                                    "bsonType": "number",
                                    "description": "must be a number and is required"
                                }
                            }
                        }
                    },
                    "replies": {
                        'bsonType': ['array', 'null'],

                        "items": {
                            "bsonType": "object",
                            "required": ["user", "ts"],
                            "properties": {
                                "user": {
                                    "bsonType": "string",
                                    "description": "must be a string and is required"
                                },
                                "ts": {
                                    "bsonType": "string",
                                    "description": "must be a string and is required"
                                }
                            }
                        }
                    }
                }
            }
        }


        try:
            self.db.create_collection("users")
            self.db.create_collection("channels")
            self.db.create_collection("messages")
        except Exception as e:
            print("error: ", e)

        self.db.command("collMod", "users", validator=self.user_validator)
        self.db.command("collMod", "channels", validator=self.channel_validator)
        self.db.command("collMod", "messages", validator=self.message_validator)



    def list_collections(self):
        return self.db.list_collection_names()
    
    def get_validation(self, collection_name: str) -> dict:
        self.check_if_collection_exist(collection_name)
        return self.db.get_collection(collection_name).options()
    
    def check_if_collection_exist(self, collection_name: str):
        if not self.list_collections().__contains__(collection_name):
            raise Exception(f"Collection, {collection_name} not found.")

    def insert_to_collection(self, collection_name, data):
        self.check_if_collection_exist(collection_name)
        collection = self.db[collection_name]
        return collection.insert_one(data)

    def insert_many_to_collection(self, collection_name, data):
        self.check_if_collection_exist(collection_name)
        result = self.db[collection_name].insert_many(data)
        return result.inserted_ids



    def find_all(self, collection_name):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find()

    def find(self, collection_name, key, value):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find({key: value})
    
    def find_by_id(self, collection_name, _id):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find

    def find_one(self, collection_name, key, value):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find_one({key: value})

# %%
db = DBWithSchema()
# Out:
# error:  collection users already exists

# %% [markdown]
# ## Insert all users into the mongo database

# %%
all_users = []
for user in data_loader.users:
    cur_user = {"user_id": user["id"], "real_name": user["real_name"]}
    all_users.append(cur_user)
    
print("total users: ", len(all_users))
print(all_users[:10])
# Out:
# total users:  71
# [{'user_id': 'U03T89ACUUW', 'real_name': 'Carlos Gross'}, {'user_id': 'U03TEPYRM2P', 'real_name': 'Garrett Bell'}, {'user_id': 'U03TNP8Q8CT', 'real_name': 'Bethany George'}, {'user_id': 'U03TT5KEYCF', 'real_name': 'Luis Ingram'}, {'user_id': 'U03TX2VN6H5', 'real_name': 'Nicole Kim'}, {'user_id': 'U03U1FNPEUX', 'real_name': 'Joshua Rhodes'}, {'user_id': 'U03U1FQKEMV', 'real_name': 'Steven Garcia'}, {'user_id': 'U03U1GHT39V', 'real_name': 'Joseph Diaz'}, {'user_id': 'U03U1HAG9TR', 'real_name': 'Robert Carter'}, {'user_id': 'U03U1J51VFZ', 'real_name': 'Cheryl Hudson'}]

# %%
inserted_records = db.insert_many_to_collection('users', all_users)
print(inserted_records)
# Out:
# [ObjectId('656780b6cd32dd8246eb8e1c'), ObjectId('656780b6cd32dd8246eb8e1d'), ObjectId('656780b6cd32dd8246eb8e1e'), ObjectId('656780b6cd32dd8246eb8e1f'), ObjectId('656780b6cd32dd8246eb8e20'), ObjectId('656780b6cd32dd8246eb8e21'), ObjectId('656780b6cd32dd8246eb8e22'), ObjectId('656780b6cd32dd8246eb8e23'), ObjectId('656780b6cd32dd8246eb8e24'), ObjectId('656780b6cd32dd8246eb8e25'), ObjectId('656780b6cd32dd8246eb8e26'), ObjectId('656780b6cd32dd8246eb8e27'), ObjectId('656780b6cd32dd8246eb8e28'), ObjectId('656780b6cd32dd8246eb8e29'), ObjectId('656780b6cd32dd8246eb8e2a'), ObjectId('656780b6cd32dd8246eb8e2b'), ObjectId('656780b6cd32dd8246eb8e2c'), ObjectId('656780b6cd32dd8246eb8e2d'), ObjectId('656780b6cd32dd8246eb8e2e'), ObjectId('656780b6cd32dd8246eb8e2f'), ObjectId('656780b6cd32dd8246eb8e30'), ObjectId('656780b6cd32dd8246eb8e31'), ObjectId('656780b6cd32dd8246eb8e32'), ObjectId('656780b6cd32dd8246eb8e33'), ObjectId('656780b6cd32dd8246eb8e34'), ObjectId('656780b6cd32dd8246eb8e35'), ObjectId('656780b6cd32dd8246eb8e36'), ObjectId('656780b6cd32dd8246eb8e37'), ObjectId('656780b6cd32dd8246eb8e38'), ObjectId('656780b6cd32dd8246eb8e39'), ObjectId('656780b6cd32dd8246eb8e3a'), ObjectId('656780b6cd32dd8246eb8e3b'), ObjectId('656780b6cd32dd8246eb8e3c'), ObjectId('656780b6cd32dd8246eb8e3d'), ObjectId('656780b6cd32dd8246eb8
),
#  'real_name': 'April Lucas',
#  'user_id': 'U03UG32J3PC'}
# {'_id': ObjectId('656765d0309ab36f1dbec84d'),
#  'real_name': 'Phillip Atkins',
#  'user_id': 'U03UG4Q7V42'}
# {'_id': ObjectId('656765d0309ab36f1dbec84e'),
#  'real_name': 'Melissa Ingram',
#  'user_id': 'U03UG569P7U'}
# {'_id': ObjectId('656765d0309ab36f1dbec84f'),
#  'real_name': 'Nancy Craig',
#  'user_id': 'U03UG5VFN03'}
# {'_id': ObjectId('656765d0309ab36f1dbec850'),
#  'real_name': 'Dustin Wilson',
#  'user_id': 'U03UGB3T3MY'}
# {'_id': ObjectId('656765d0309ab36f1dbec851'),
#  'real_name': 'Brenda Hernandez',
#  'user_id': 'U03UH397319'}
# {'_id': ObjectId('656765d0309ab36f1dbec852'),
#  'real_name': 'Holly Whitaker',
#  'user_id': 'U03UH760JQK'}
# {'_id': ObjectId('656765d0309ab36f1dbec853'),
#  'real_name': 'Yvonne Gonzalez',
#  'user_id': 'U03UHB8CXDY'}
# {'_id': ObjectId('656765d0309ab36f1dbec854'),
#  'real_name': 'Vernon Garcia',
#  'user_id': 'U03UJGFG2HJ'}
# {'_id': ObjectId('656765d0309ab36f1dbec855'),
#  'real_name': 'Judith Bolton',
#  'user_id': 'U03UJGP0C68'}
# {'_id': ObjectId('656765d0309ab36f1dbec856'),
#  'real_name': 'Katie Dickerson',
#  'user_id': 'U03UJGRN5E0'}
# {'_id': ObjectId('656765d0309ab36f1dbec857'),
#  'real_name': 'Kelly Soto',
#  'user_id': 'U03UJH1EQQL'}
# {'_id': ObjectId('656765d0309ab36f1dbec858'),
#  'real_name': 'Brian Odom',
#  'user_id': 'U03UJKJGRAQ'}
# {'_id': ObjectId('656765d0309ab36f1dbec859'),
#  'real_name': 'Michelle Lewis',
#  'user_id': 'U03UJN29Y4C'}
# {'_id': ObjectId('656765d0309ab36f1dbec85a'),
#  'real_name': 'Claudia Riddle',
#  'user_id': 'U03UK9CB71A'}
# {'_id': ObjectId('656765d0309ab36f1dbec85b'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('656765d0309ab36f1dbec85c'),
#  'real_name': 'Brittany Garcia',
#  'user_id': 'U03UKL27B0R'}
# {'_id': ObjectId('656765d0309ab36f1dbec85d'),
#  'real_name': 'Samantha Lee',
#  'user_id': 'U03UL5LSTG9'}
# {'_id': ObjectId('656765d0309ab36f1dbec85e'),
#  'real_name': 'Michele Sparks',
#  'user_id': 'U03UP7V9Q57'}
# {'_id': ObjectId('656765d0309ab36f1dbec85f'),
#  'real_name': 'David Scott',
#  'user_id': 'U03UR2LQ4DR'}
# {'_id': ObjectId('656765d0309ab36f1dbec860'),
#  'real_name': 'Veronica Padilla',
#  'user_id': 'U03UUMM7Y8H'}
# {'_id': ObjectId('656765d0309ab36f1dbec861'),
#  'real_name': 'Samuel King',
#  'user_id': 'U03UUMR26Q1'}
# {'_id': ObjectId('656765d0309ab36f1dbec862'),
#  'real_name': 'Eric Myers',
#  'user_id': 'U03UUN8M4RX'}
# {'_id': ObjectId('656765d0309ab36f1dbec863'),
#  'real_name': 'Mark Crawford',
#  'user_id': 'U03UUP56MDF'}
#  'real_name': 'Judith Bolton',
#  'user_id': 'U03UJGP0C68'}
# {'_id': ObjectId('65676706309ab36f1dbec8c6'),
#  'real_name': 'Katie Dickerson',
#  'user_id': 'U03UJGRN5E0'}
# {'_id': ObjectId('65676706309ab36f1dbec8c7'),
#  'real_name': 'Kelly Soto',
#  'user_id': 'U03UJH1EQQL'}
# {'_id': ObjectId('65676706309ab36f1dbec8c8'),
#  'real_name': 'Brian Odom',
#  'user_id': 'U03UJKJGRAQ'}
# {'_id': ObjectId('65676706309ab36f1dbec8c9'),
#  'real_name': 'Michelle Lewis',
#  'user_id': 'U03UJN29Y4C'}
# {'_id': ObjectId('65676706309ab36f1dbec8ca'),
#  'real_name': 'Claudia Riddle',
#  'user_id': 'U03UK9CB71A'}
# {'_id': ObjectId('65676706309ab36f1dbec8cb'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('65676706309ab36f1dbec8cc'),
#  'real_name': 'Brittany Garcia',
#  'user_id': 'U03UKL27B0R'}
# {'_id': ObjectId('65676706309ab36f1dbec8cd'),
#  'real_name': 'Samantha Lee',
#  'user_id': 'U03UL5LSTG9'}
# {'_id': ObjectId('65676706309ab36f1dbec8ce'),
#  'real_name': 'Michele Sparks',
#  'user_id': 'U03UP7V9Q57'}
# {'_id': ObjectId('65676706309ab36f1dbec8cf'),
#  'real_name': 'David Scott',
#  'user_id': 'U03UR2LQ4DR'}
# {'_id': ObjectId('65676706309ab36f1dbec8d0'),
#  'real_name': 'Veronica Padilla',
#  'user_id': 'U03UUMM7Y8H'}
# {'_id': ObjectId('65676706309ab36f1dbec8d1'),
#  'real_name': 'Samuel King',
#  'user_id': 'U03UUMR26Q1'}
# {'_id': ObjectId('65676706309ab36f1dbec8d2'),
#  'real_name': 'Eric Myers',
#  'user_id': 'U03UUN8M4RX'}
# {'_id': ObjectId('65676706309ab36f1dbec8d3'),
#  'real_name': 'Mark Crawford',
#  'user_id': 'U03UUP56MDF'}
# {'_id': ObjectId('65676706309ab36f1dbec8d4'),
#  'real_name': 'Amy Leon',
#  'user_id': 'U03UUR571A5'}
# {'_id': ObjectId('65676706309ab36f1dbec8d5'),
#  'real_name': 'Jodi Lyons',
#  'user_id': 'U03UUS0MZCZ'}
# {'_id': ObjectId('65676706309ab36f1dbec8d6'),
#  'real_name': 'Travis Butler',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('65676706309ab36f1dbec8d7'),
#  'real_name': 'Patrick Hernandez',
#  'user_id': 'U03UYNR4TS4'}
# {'_id': ObjectId('65676706309ab36f1dbec8d8'),
#  'real_name': 'Vanessa Norman',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676706309ab36f1dbec8d9'),
#  'real_name': 'Debra Lawrence',
#  'user_id': 'U03V5Q9N516'}
# {'_id': ObjectId('65676706309ab36f1dbec8da'),
#  'real_name': 'Paula Bryant',
#  'user_id': 'U03V61VGQG0'}
# {'_id': ObjectId('65676706309ab36f1dbec8db'),
#  'real_name': 'Cristian Wilson',
#  'user_id': 'U03V6HMRPGQ'}
# {'_id': ObjectId('65676706309ab36f1dbec8dc'),
#  'real_name': 'Ashley Hamilton',
#  'user_id': 'U03V785NLSU'}
# {'_id': ObjectId('65676706309ab36f1dbec8dd'),
#  'real_name': 'Mandy Sweeney',
#  'user_id': 'U03V8LHPDME'}
# {'_id': ObjectId('65676706309ab36f1dbec8de'),
#  'real_name': 'Paul Brown',
#  'user_id': 'U03VAH809FC'}
# {'_id': ObjectId('65676706309ab36f1dbec8df'),
#  'real_name': 'Kathleen Phillips',
#  'user_id': 'U0401GU4W6L'}
# {'_id': ObjectId('65676706309ab36f1dbec8e0'),
#  'real_name': 'Kenneth Fitzgerald',
#  'user_id': 'U0418T6CD1B'}
# {'_id': ObjectId('65676706309ab36f1dbec8e1'),
#  'real_name': 'Audrey Parsons',
#  'user_id': 'U04718Y7SQ0'}
# {'_id': ObjectId('65676db8309ab36f1dbf130a'),
#  'real_name': 'Carlos Gross',
#  'user_id': 'U03T89ACUUW'}
# {'_id': ObjectId('65676db8309ab36f1dbf130b'),
#  'real_name': 'Garrett Bell',
#  'user_id': 'U03TEPYRM2P'}
# {'_id': ObjectId('65676db8309ab36f1dbf130c'),
#  'real_name': 'Bethany George',
#  'user_id': 'U03TNP8Q8CT'}
# {'_id': ObjectId('65676db8309ab36f1dbf130d'),
#  'real_name': 'Luis Ingram',
#  'user_id': 'U03TT5KEYCF'}
# {'_id': ObjectId('65676db8309ab36f1dbf130e'),
#  'real_name': 'Nicole Kim',
#  'user_id': 'U03TX2VN6H5'}
# {'_id': ObjectId('65676db8309ab36f1dbf130f'),
#  'real_name': 'Joshua Rhodes',
#  'user_id': 'U03U1FNPEUX'}
# {'_id': ObjectId('65676db8309ab36f1dbf1310'),
#  'real_name': 'Steven Garcia',
#  'user_id': 'U03U1FQKEMV'}
# {'_id': ObjectId('65676db8309ab36f1dbf1311'),
#  'real_name': 'Joseph Diaz',
#  'user_id': 'U03U1GHT39V'}
# {'_id': ObjectId('65676db8309ab36f1dbf1312'),
#  'real_name': 'Robert Carter',
#  'user_id': 'U03U1HAG9TR'}
# {'_id': ObjectId('65676db8309ab36f1dbf1313'),
#  'real_name': 'Cheryl Hudson',
#  'user_id': 'U03U1J51VFZ'}
# {'_id': ObjectId('65676db8309ab36f1dbf1314'),
#  'real_name': 'Allison Thompson',
#  'user_id': 'U03U4GULU3Y'}
# {'_id': ObjectId('65676db8309ab36f1dbf1315'),
#  'real_name': 'Katherine Foster',
#  'user_id': 'U03U93GNNVB'}
# {'_id': ObjectId('65676db8309ab36f1dbf1316'),
#  'real_name': 'John Romero',
#  'user_id': 'U03U9DB7REG'}
# {'_id': ObjectId('65676db8309ab36f1dbf1317'),
#  'real_name': 'Nicholas Friedman',
#  'user_id': 'U03U9EJR362'}
# {'_id': ObjectId('65676db8309ab36f1dbf1318'),
#  'real_name': 'Anita Rodriguez',
#  'user_id': 'U03U9FWPNCE'}
# {'_id': ObjectId('65676db8309ab36f1dbf1319'),
#  'real_name': 'Gary Thomas',
#  'user_id': 'U03UAKATQ22'}
# {'_id': ObjectId('65676db8309ab36f1dbf131a'),
#  'real_name': 'Erica Munoz',
#  'user_id': 'U03UCCRJME2'}
# {'_id': ObjectId('65676db8309ab36f1dbf131b'),
#  'real_name': 'Michael Gonzalez',
#  'user_id': 'U03UD4FEDHB'}
# {'_id': ObjectId('65676db8309ab36f1dbf131c'),
#  'real_name': 'Elizabeth Hall',
#  'user_id': 'U03UD5B7C3X'}
# {'_id': ObjectId('65676db8309ab36f1dbf131d'),
#  'real_name': 'Ryan Cochran',
#  'user_id': 'U03UD5K7HAR'}
# {'_id': ObjectId('65676db8309ab36f1dbf131e'),
#  'real_name': 'Randy Miller',
#  'user_id': 'U03UD63A8PP'}
# {'_id': ObjectId('65676db8309ab36f1dbf131f'),
#  'real_name': 'Brady Rhodes',
#  'user_id': 'U03UD68RQH3'}
# {'_id': ObjectId('65676db8309ab36f1dbf1320'),
#  'real_name': 'Dana Parks',
#  'user_id': 'U03UDA3R8S2'}
# {'_id': ObjectId('65676db8309ab36f1dbf1321'),
#  'real_name': 'Patricia Thomas',
#  'user_id': 'U03UDBUL7CL'}
# {'_id': ObjectId('65676db8309ab36f1dbf1322'),
#  'real_name': 'Glen Pennington',
#  'user_id': 'U03UDKKESB1'}
# {'_id': ObjectId('65676db8309ab36f1dbf1323'),
#  'real_name': 'Blake Scott',
#  'user_id': 'U03UFT20ZJR'}
# {'_id': ObjectId('65676db8309ab36f1dbf1324'),
#  'real_name': 'Miguel Herring',
#  'user_id': 'U03UFV7HFNF'}
# {'_id': ObjectId('65676db8309ab36f1dbf1325'),
#  'real_name': 'Anthony Galloway',
#  'user_id': 'U03UFV7TUTV'}
# {'_id': ObjectId('65676db8309ab36f1dbf1326'),
#  'real_name': 'Christopher Case',
#  'user_id': 'U03UG03HQ2F'}
# {'_id': ObjectId('65676db8309ab36f1dbf1327'),
#  'real_name': 'Willie Yang',
#  'user_id': 'U03UG0SFHGT'}
# {'_id': ObjectId('65676db8309ab36f1dbf1328'),
#  'real_name': 'Daniel Brown',
#  'user_id': 'U03UG0YHAUT'}
# {'_id': ObjectId('65676db8309ab36f1dbf1329'),
#  'real_name': 'Carol Kaiser',
#  'user_id': 'U03UG1RTXAP'}
# {'_id': ObjectId('65676db8309ab36f1dbf132a'),
#  'real_name': 'Jennifer Foley',
#  'user_id': 'U03UG1Z21JP'}
# {'_id': ObjectId('65676db8309ab36f1dbf132b'),
#  'real_name': 'April Lucas',
#  'user_id': 'U03UG32J3PC'}
# {'_id': ObjectId('65676db8309ab36f1dbf132c'),
#  'real_name': 'Phillip Atkins',
#  'user_id': 'U03UG4Q7V42'}
# {'_id': ObjectId('65676db8309ab36f1dbf132d'),
#  'real_name': 'Melissa Ingram',
#  'user_id': 'U03UG569P7U'}
# {'_id': ObjectId('65676db8309ab36f1dbf132e'),
#  'real_name': 'Nancy Craig',
#  'user_id': 'U03UG5VFN03'}
# {'_id': ObjectId('65676db8309ab36f1dbf132f'),
#  'real_name': 'Dustin Wilson',
#  'user_id': 'U03UGB3T3MY'}
# {'_id': ObjectId('65676db8309ab36f1dbf1330'),
#  'real_name': 'Brenda Hernandez',
#  'user_id': 'U03UH397319'}
# {'_id': ObjectId('65676db8309ab36f1dbf1331'),
#  'real_name': 'Holly Whitaker',
#  'user_id': 'U03UH760JQK'}
# {'_id': ObjectId('65676db8309ab36f1dbf1332'),
#  'real_name': 'Yvonne Gonzalez',
#  'user_id': 'U03UHB8CXDY'}
# {'_id': ObjectId('65676db8309ab36f1dbf1333'),
#  'real_name': 'Vernon Garcia',
#  'user_id': 'U03UJGFG2HJ'}
# {'_id': ObjectId('65676db8309ab36f1dbf1334'),
#  'real_name': 'Judith Bolton',
#  'user_id': 'U03UJGP0C68'}
# {'_id': ObjectId('65676db8309ab36f1dbf1335'),
#  'real_name': 'Katie Dickerson',
#  'user_id': 'U03UJGRN5E0'}
# {'_id': ObjectId('65676db8309ab36f1dbf1336'),
#  'real_name': 'Kelly Soto',
#  'user_id': 'U03UJH1EQQL'}
# {'_id': ObjectId('65676db8309ab36f1dbf1337'),
#  'real_name': 'Brian Odom',
#  'user_id': 'U03UJKJGRAQ'}
# {'_id': ObjectId('65676db8309ab36f1dbf1338'),
#  'real_name': 'Michelle Lewis',
#  'user_id': 'U03UJN29Y4C'}
# {'_id': ObjectId('65676db8309ab36f1dbf1339'),
#  'real_name': 'Claudia Riddle',
#  'user_id': 'U03UK9CB71A'}
# {'_id': ObjectId('65676db8309ab36f1dbf133a'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('65676db8309ab36f1dbf133b'),
),
#  'real_name': 'Jennifer Foley',
#  'user_id': 'U03UG1Z21JP'}
# {'_id': ObjectId('65676e48309ab36f1dbf139a'),
#  'real_name': 'April Lucas',
#  'user_id': 'U03UG32J3PC'}
# {'_id': ObjectId('65676e48309ab36f1dbf139b'),
#  'real_name': 'Phillip Atkins',
#  'user_id': 'U03UG4Q7V42'}
# {'_id': ObjectId('65676e48309ab36f1dbf139c'),
#  'real_name': 'Melissa Ingram',
#  'user_id': 'U03UG569P7U'}
# {'_id': ObjectId('65676e48309ab36f1dbf139d'),
#  'real_name': 'Nancy Craig',
#  'user_id': 'U03UG5VFN03'}
# {'_id': ObjectId('65676e48309ab36f1dbf139e'),
#  'real_name': 'Dustin Wilson',
#  'user_id': 'U03UGB3T3MY'}
# {'_id': ObjectId('65676e48309ab36f1dbf139f'),
#  'real_name': 'Brenda Hernandez',
#  'user_id': 'U03UH397319'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a0'),
#  'real_name': 'Holly Whitaker',
#  'user_id': 'U03UH760JQK'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a1'),
#  'real_name': 'Yvonne Gonzalez',
#  'user_id': 'U03UHB8CXDY'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a2'),
#  'real_name': 'Vernon Garcia',
#  'user_id': 'U03UJGFG2HJ'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a3'),
#  'real_name': 'Judith Bolton',
#  'user_id': 'U03UJGP0C68'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a4'),
#  'real_name': 'Katie Dickerson',
#  'user_id': 'U03UJGRN5E0'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a5'),
#  'real_name': 'Kelly Soto',
#  'user_id': 'U03UJH1EQQL'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a6'),
#  'real_name': 'Brian Odom',
#  'user_id': 'U03UJKJGRAQ'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a7'),
#  'real_name': 'Michelle Lewis',
#  'user_id': 'U03UJN29Y4C'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a8'),
#  'real_name': 'Claudia Riddle',
#  'user_id': 'U03UK9CB71A'}
# {'_id': ObjectId('65676e48309ab36f1dbf13a9'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('65676e48309ab36f1dbf13aa'),
#  'real_name': 'Brittany Garcia',
#  'user_id': 'U03UKL27B0R'}
# {'_id': ObjectId('65676e48309ab36f1dbf13ab'),
#  'real_name': 'Samantha Lee',
#  'user_id': 'U03UL5LSTG9'}
# {'_id': ObjectId('65676e48309ab36f1dbf13ac'),
#  'real_name': 'Michele Sparks',
#  'user_id': 'U03UP7V9Q57'}
# {'_id': ObjectId('65676e48309ab36f1dbf13ad'),
#  'real_name': 'David Scott',
#  'user_id': 'U03UR2LQ4DR'}
# {'_id': ObjectId('65676e48309ab36f1dbf13ae'),
#  'real_name': 'Veronica Padilla',
#  'user_id': 'U03UUMM7Y8H'}
# {'_id': ObjectId('65676e48309ab36f1dbf13af'),
#  'real_name': 'Samuel King',
#  'user_id': 'U03UUMR26Q1'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b0'),
#  'real_name': 'Eric Myers',
#  'user_id': 'U03UUN8M4RX'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b1'),
#  'real_name': 'Mark Crawford',
#  'user_id': 'U03UUP56MDF'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b2'),
#  'real_name': 'Amy Leon',
#  'user_id': 'U03UUR571A5'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b3'),
#  'real_name': 'Jodi Lyons',
#  'user_id': 'U03UUS0MZCZ'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b4'),
#  'real_name': 'Travis Butler',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b5'),
#  'real_name': 'Patrick Hernandez',
#  'user_id': 'U03UYNR4TS4'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b6'),
#  'real_name': 'Vanessa Norman',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b7'),
#  'real_name': 'Debra Lawrence',
#  'user_id': 'U03V5Q9N516'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b8'),
#  'real_name': 'Paula Bryant',
#  'user_id': 'U03V61VGQG0'}
# {'_id': ObjectId('65676e48309ab36f1dbf13b9'),
#  'real_name': 'Cristian Wilson',
#  'user_id': 'U03V6HMRPGQ'}
# {'_id': ObjectId('65676e48309ab36f1dbf13ba'),
#  'real_name': 'Ashley Hamilton',
#  'user_id': 'U03V785NLSU'}
# {'_id': ObjectId('65676e48309ab36f1dbf13bb'),
#  'real_name': 'Mandy Sweeney',
#  'user_id': 'U03V8LHPDME'}
# {'_id': ObjectId('65676e48309ab36f1dbf13bc'),
#  'real_name': 'Paul Brown',
#  'user_id': 'U03VAH809FC'}
# {'_id': ObjectId('65676e48309ab36f1dbf13bd'),
#  'real_name': 'Kathleen Phillips',
#  'user_id': 'U0401GU4W6L'}
# {'_id': ObjectId('65676e48309ab36f1dbf13be'),
#  'real_name': 'Kenneth Fitzgerald',
#  'user_id': 'U0418T6CD1B'}
# {'_id': ObjectId('65676e48309ab36f1dbf13bf'),
#  'real_name': 'Audrey Parsons',
#  'user_id': 'U04718Y7SQ0'}
# {'_id': ObjectId('65676f42309ab36f1dbf5de8'),
#  'real_name': 'Carlos Gross',
#  'user_id': 'U03T89ACUUW'}
# {'_id': ObjectId('65676f42309ab36f1dbf5de9'),
#  'real_name': 'Garrett Bell',
#  'user_id': 'U03TEPYRM2P'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dea'),
#  'real_name': 'Bethany George',
#  'user_id': 'U03TNP8Q8CT'}
# {'_id': ObjectId('65676f42309ab36f1dbf5deb'),
#  'real_name': 'Luis Ingram',
#  'user_id': 'U03TT5KEYCF'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dec'),
#  'real_name': 'Nicole Kim',
#  'user_id': 'U03TX2VN6H5'}
# {'_id': ObjectId('65676f42309ab36f1dbf5ded'),
#  'real_name': 'Joshua Rhodes',
#  'user_id': 'U03U1FNPEUX'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dee'),
#  'real_name': 'Steven Garcia',
#  'user_id': 'U03U1FQKEMV'}
# {'_id': ObjectId('65676f42309ab36f1dbf5def'),
#  'real_name': 'Joseph Diaz',
#  'user_id': 'U03U1GHT39V'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df0'),
#  'real_name': 'Robert Carter',
#  'user_id': 'U03U1HAG9TR'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df1'),
#  'real_name': 'Cheryl Hudson',
#  'user_id': 'U03U1J51VFZ'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df2'),
#  'real_name': 'Allison Thompson',
#  'user_id': 'U03U4GULU3Y'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df3'),
#  'real_name': 'Katherine Foster',
#  'user_id': 'U03U93GNNVB'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df4'),
#  'real_name': 'John Romero',
#  'user_id': 'U03U9DB7REG'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df5'),
#  'real_name': 'Nicholas Friedman',
#  'user_id': 'U03U9EJR362'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df6'),
#  'real_name': 'Anita Rodriguez',
#  'user_id': 'U03U9FWPNCE'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df7'),
#  'real_name': 'Gary Thomas',
#  'user_id': 'U03UAKATQ22'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df8'),
#  'real_name': 'Erica Munoz',
#  'user_id': 'U03UCCRJME2'}
# {'_id': ObjectId('65676f42309ab36f1dbf5df9'),
#  'real_name': 'Michael Gonzalez',
#  'user_id': 'U03UD4FEDHB'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dfa'),
#  'real_name': 'Elizabeth Hall',
#  'user_id': 'U03UD5B7C3X'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dfb'),
#  'real_name': 'Ryan Cochran',
#  'user_id': 'U03UD5K7HAR'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dfc'),
#  'real_name': 'Randy Miller',
#  'user_id': 'U03UD63A8PP'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dfd'),
#  'real_name': 'Brady Rhodes',
#  'user_id': 'U03UD68RQH3'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dfe'),
#  'real_name': 'Dana Parks',
#  'user_id': 'U03UDA3R8S2'}
# {'_id': ObjectId('65676f42309ab36f1dbf5dff'),
#  'real_name': 'Patricia Thomas',
#  'user_id': 'U03UDBUL7CL'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e00'),
#  'real_name': 'Glen Pennington',
#  'user_id': 'U03UDKKESB1'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e01'),
#  'real_name': 'Blake Scott',
#  'user_id': 'U03UFT20ZJR'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e02'),
#  'real_name': 'Miguel Herring',
#  'user_id': 'U03UFV7HFNF'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e03'),
#  'real_name': 'Anthony Galloway',
#  'user_id': 'U03UFV7TUTV'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e04'),
#  'real_name': 'Christopher Case',
#  'user_id': 'U03UG03HQ2F'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e05'),
#  'real_name': 'Willie Yang',
#  'user_id': 'U03UG0SFHGT'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e06'),
#  'real_name': 'Daniel Brown',
#  'user_id': 'U03UG0YHAUT'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e07'),
#  'real_name': 'Carol Kaiser',
#  'user_id': 'U03UG1RTXAP'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e08'),
#  'real_name': 'Jennifer Foley',
#  'user_id': 'U03UG1Z21JP'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e09'),
#  'real_name': 'April Lucas',
#  'user_id': 'U03UG32J3PC'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e0a'),
#  'real_name': 'Phillip Atkins',
#  'user_id': 'U03UG4Q7V42'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e0b'),
#  'real_name': 'Melissa Ingram',
#  'user_id': 'U03UG569P7U'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e0c'),
#  'real_name': 'Nancy Craig',
#  'user_id': 'U03UG5VFN03'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e0d'),
#  'real_name': 'Dustin Wilson',
#  'user_id': 'U03UGB3T3MY'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e0e'),
#  'real_name': 'Brenda Hernandez',
#  'user_id': 'U03UH397319'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e0f'),
#  'real_name': 'Holly Whitaker',
#  'user_id': 'U03UH760JQK'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e10'),
#  'real_name': 'Yvonne Gonzalez',
#  'user_id': 'U03UHB8CXDY'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e11'),
#  'real_name': 'Vernon Garcia',
#  'user_id': 'U03UJGFG2HJ'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e12'),
#  'real_name': 'Judith Bolton',
#  'user_id': 'U03UJGP0C68'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e13'),
#  'real_name': 'Katie Dickerson',
#  'user_id': 'U03UJGRN5E0'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e14'),
#  'real_name': 'Kelly Soto',
#  'user_id': 'U03UJH1EQQL'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e15'),
#  'real_name': 'Brian Odom',
#  'user_id': 'U03UJKJGRAQ'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e16'),
#  'real_name': 'Michelle Lewis',
#  'user_id': 'U03UJN29Y4C'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e17'),
#  'real_name': 'Claudia Riddle',
#  'user_id': 'U03UK9CB71A'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e18'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e19'),
#  'real_name': 'Brittany Garcia',
#  'user_id': 'U03UKL27B0R'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e1a'),
#  'real_name': 'Samantha Lee',
#  'user_id': 'U03UL5LSTG9'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e1b'),
#  'real_name': 'Michele Sparks',
#  'user_id': 'U03UP7V9Q57'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e1c'),
#  'real_name': 'David Scott',
#  'user_id': 'U03UR2LQ4DR'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e1d'),
#  'real_name': 'Veronica Padilla',
#  'user_id': 'U03UUMM7Y8H'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e1e'),
#  'real_name': 'Samuel King',
#  'user_id': 'U03UUMR26Q1'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e1f'),
#  'real_name': 'Eric Myers',
#  'user_id': 'U03UUN8M4RX'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e20'),
#  'real_name': 'Mark Crawford',
#  'user_id': 'U03UUP56MDF'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e21'),
#  'real_name': 'Amy Leon',
#  'user_id': 'U03UUR571A5'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e22'),
#  'real_name': 'Jodi Lyons',
#  'user_id': 'U03UUS0MZCZ'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e23'),
#  'real_name': 'Travis Butler',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e24'),
#  'real_name': 'Patrick Hernandez',
#  'user_id': 'U03UYNR4TS4'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e25'),
#  'real_name': 'Vanessa Norman',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e26'),
#  'real_name': 'Debra Lawrence',
#  'user_id': 'U03V5Q9N516'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e27'),
#  'real_name': 'Paula Bryant',
#  'user_id': 'U03V61VGQG0'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e28'),
#  'real_name': 'Cristian Wilson',
#  'user_id': 'U03V6HMRPGQ'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e29'),
#  'real_name': 'Ashley Hamilton',
#  'user_id': 'U03V785NLSU'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e2a'),
#  'real_name': 'Mandy Sweeney',
#  'user_id': 'U03V8LHPDME'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e2b'),
#  'real_name': 'Paul Brown',
#  'user_id': 'U03VAH809FC'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e2c'),
#  'real_name': 'Kathleen Phillips',
#  'user_id': 'U0401GU4W6L'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e2d'),
#  'real_name': 'Kenneth Fitzgerald',
#  'user_id': 'U0418T6CD1B'}
# {'_id': ObjectId('65676f42309ab36f1dbf5e2e'),
#  'real_name': 'Audrey Parsons',
#  'user_id': 'U04718Y7SQ0'}
# {'_id': ObjectId('65677125309ab36f1dc03c57'),
#  'real_name': 'Carlos Gross',
#  'user_id': 'U03T89ACUUW'}
# {'_id': ObjectId('65677125309ab36f1dc03c58'),
#  'real_name': 'Garrett Bell',
#  'user_id': 'U03TEPYRM2P'}
# {'_id': ObjectId('65677125309ab36f1dc03c59'),
#  'real_name': 'Bethany George',
#  'user_id': 'U03TNP8Q8CT'}
# {'_id': ObjectId('65677125309ab36f1dc03c5a'),
#  'real_name': 'Luis Ingram',
#  'user_id': 'U03TT5KEYCF'}
# {'_id': ObjectId('65677125309ab36f1dc03c5b'),
#  'real_name': 'Nicole Kim',
#  'user_id': 'U03TX2VN6H5'}
# {'_id': ObjectId
}
# {'_id': ObjectId('65677f69cd32dd8246eb43b8'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('65677f69cd32dd8246eb43b9'),
#  'real_name': 'Brittany Garcia',
#  'user_id': 'U03UKL27B0R'}
# {'_id': ObjectId('65677f69cd32dd8246eb43ba'),
#  'real_name': 'Samantha Lee',
#  'user_id': 'U03UL5LSTG9'}
# {'_id': ObjectId('65677f69cd32dd8246eb43bb'),
#  'real_name': 'Michele Sparks',
#  'user_id': 'U03UP7V9Q57'}
# {'_id': ObjectId('65677f69cd32dd8246eb43bc'),
#  'real_name': 'David Scott',
#  'user_id': 'U03UR2LQ4DR'}
# {'_id': ObjectId('65677f69cd32dd8246eb43bd'),
#  'real_name': 'Veronica Padilla',
#  'user_id': 'U03UUMM7Y8H'}
# {'_id': ObjectId('65677f69cd32dd8246eb43be'),
#  'real_name': 'Samuel King',
#  'user_id': 'U03UUMR26Q1'}
# {'_id': ObjectId('65677f69cd32dd8246eb43bf'),
#  'real_name': 'Eric Myers',
#  'user_id': 'U03UUN8M4RX'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c0'),
#  'real_name': 'Mark Crawford',
#  'user_id': 'U03UUP56MDF'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c1'),
#  'real_name': 'Amy Leon',
#  'user_id': 'U03UUR571A5'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c2'),
#  'real_name': 'Jodi Lyons',
#  'user_id': 'U03UUS0MZCZ'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c3'),
#  'real_name': 'Travis Butler',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c4'),
#  'real_name': 'Patrick Hernandez',
#  'user_id': 'U03UYNR4TS4'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c5'),
#  'real_name': 'Vanessa Norman',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c6'),
#  'real_name': 'Debra Lawrence',
#  'user_id': 'U03V5Q9N516'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c7'),
#  'real_name': 'Paula Bryant',
#  'user_id': 'U03V61VGQG0'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c8'),
#  'real_name': 'Cristian Wilson',
#  'user_id': 'U03V6HMRPGQ'}
# {'_id': ObjectId('65677f69cd32dd8246eb43c9'),
#  'real_name': 'Ashley Hamilton',
#  'user_id': 'U03V785NLSU'}
# {'_id': ObjectId('65677f69cd32dd8246eb43ca'),
#  'real_name': 'Mandy Sweeney',
#  'user_id': 'U03V8LHPDME'}
# {'_id': ObjectId('65677f69cd32dd8246eb43cb'),
#  'real_name': 'Paul Brown',
#  'user_id': 'U03VAH809FC'}
# {'_id': ObjectId('65677f69cd32dd8246eb43cc'),
#  'real_name': 'Kathleen Phillips',
#  'user_id': 'U0401GU4W6L'}
# {'_id': ObjectId('65677f69cd32dd8246eb43cd'),
#  'real_name': 'Kenneth Fitzgerald',
#  'user_id': 'U0418T6CD1B'}
# {'_id': ObjectId('65677f69cd32dd8246eb43ce'),
#  'real_name': 'Audrey Parsons',
#  'user_id': 'U04718Y7SQ0'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e1c'),
#  'real_name': 'Carlos Gross',
#  'user_id': 'U03T89ACUUW'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e1d'),
#  'real_name': 'Garrett Bell',
#  'user_id': 'U03TEPYRM2P'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e1e'),
#  'real_name': 'Bethany George',
#  'user_id': 'U03TNP8Q8CT'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e1f'),
#  'real_name': 'Luis Ingram',
#  'user_id': 'U03TT5KEYCF'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e20'),
#  'real_name': 'Nicole Kim',
#  'user_id': 'U03TX2VN6H5'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e21'),
#  'real_name': 'Joshua Rhodes',
#  'user_id': 'U03U1FNPEUX'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e22'),
#  'real_name': 'Steven Garcia',
#  'user_id': 'U03U1FQKEMV'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e23'),
#  'real_name': 'Joseph Diaz',
#  'user_id': 'U03U1GHT39V'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e24'),
#  'real_name': 'Robert Carter',
#  'user_id': 'U03U1HAG9TR'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e25'),
#  'real_name': 'Cheryl Hudson',
#  'user_id': 'U03U1J51VFZ'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e26'),
#  'real_name': 'Allison Thompson',
#  'user_id': 'U03U4GULU3Y'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e27'),
#  'real_name': 'Katherine Foster',
#  'user_id': 'U03U93GNNVB'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e28'),
#  'real_name': 'John Romero',
#  'user_id': 'U03U9DB7REG'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e29'),
#  'real_name': 'Nicholas Friedman',
#  'user_id': 'U03U9EJR362'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e2a'),
#  'real_name': 'Anita Rodriguez',
#  'user_id': 'U03U9FWPNCE'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e2b'),
#  'real_name': 'Gary Thomas',
#  'user_id': 'U03UAKATQ22'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e2c'),
#  'real_name': 'Erica Munoz',
#  'user_id': 'U03UCCRJME2'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e2d'),
#  'real_name': 'Michael Gonzalez',
#  'user_id': 'U03UD4FEDHB'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e2e'),
#  'real_name': 'Elizabeth Hall',
#  'user_id': 'U03UD5B7C3X'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e2f'),
#  'real_name': 'Ryan Cochran',
#  'user_id': 'U03UD5K7HAR'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e30'),
#  'real_name': 'Randy Miller',
#  'user_id': 'U03UD63A8PP'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e31'),
#  'real_name': 'Brady Rhodes',
#  'user_id': 'U03UD68RQH3'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e32'),
#  'real_name': 'Dana Parks',
#  'user_id': 'U03UDA3R8S2'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e33'),
#  'real_name': 'Patricia Thomas',
#  'user_id': 'U03UDBUL7CL'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e34'),
#  'real_name': 'Glen Pennington',
#  'user_id': 'U03UDKKESB1'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e35'),
#  'real_name': 'Blake Scott',
#  'user_id': 'U03UFT20ZJR'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e36'),
#  'real_name': 'Miguel Herring',
#  'user_id': 'U03UFV7HFNF'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e37'),
#  'real_name': 'Anthony Galloway',
#  'user_id': 'U03UFV7TUTV'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e38'),
#  'real_name': 'Christopher Case',
#  'user_id': 'U03UG03HQ2F'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e39'),
#  'real_name': 'Willie Yang',
#  'user_id': 'U03UG0SFHGT'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e3a'),
#  'real_name': 'Daniel Brown',
#  'user_id': 'U03UG0YHAUT'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e3b'),
#  'real_name': 'Carol Kaiser',
#  'user_id': 'U03UG1RTXAP'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e3c'),
#  'real_name': 'Jennifer Foley',
#  'user_id': 'U03UG1Z21JP'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e3d'),
#  'real_name': 'April Lucas',
#  'user_id': 'U03UG32J3PC'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e3e'),
#  'real_name': 'Phillip Atkins',
#  'user_id': 'U03UG4Q7V42'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e3f'),
#  'real_name': 'Melissa Ingram',
#  'user_id': 'U03UG569P7U'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e40'),
#  'real_name': 'Nancy Craig',
#  'user_id': 'U03UG5VFN03'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e41'),
#  'real_name': 'Dustin Wilson',
#  'user_id': 'U03UGB3T3MY'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e42'),
#  'real_name': 'Brenda Hernandez',
#  'user_id': 'U03UH397319'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e43'),
#  'real_name': 'Holly Whitaker',
#  'user_id': 'U03UH760JQK'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e44'),
#  'real_name': 'Yvonne Gonzalez',
#  'user_id': 'U03UHB8CXDY'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e45'),
#  'real_name': 'Vernon Garcia',
#  'user_id': 'U03UJGFG2HJ'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e46'),
#  'real_name': 'Judith Bolton',
#  'user_id': 'U03UJGP0C68'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e47'),
#  'real_name': 'Katie Dickerson',
#  'user_id': 'U03UJGRN5E0'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e48'),
#  'real_name': 'Kelly Soto',
#  'user_id': 'U03UJH1EQQL'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e49'),
#  'real_name': 'Brian Odom',
#  'user_id': 'U03UJKJGRAQ'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e4a'),
#  'real_name': 'Michelle Lewis',
#  'user_id': 'U03UJN29Y4C'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e4b'),
#  'real_name': 'Claudia Riddle',
#  'user_id': 'U03UK9CB71A'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e4c'),
#  'real_name': 'Leah Newton',
#  'user_id': 'U03UKGSDGSG'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e4d'),
#  'real_name': 'Brittany Garcia',
#  'user_id': 'U03UKL27B0R'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e4e'),
#  'real_name': 'Samantha Lee',
#  'user_id': 'U03UL5LSTG9'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e4f'),
#  'real_name': 'Michele Sparks',
#  'user_id': 'U03UP7V9Q57'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e50'),
#  'real_name': 'David Scott',
#  'user_id': 'U03UR2LQ4DR'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e51'),
#  'real_name': 'Veronica Padilla',
#  'user_id': 'U03UUMM7Y8H'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e52'),
#  'real_name': 'Samuel King',
#  'user_id': 'U03UUMR26Q1'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e53'),
#  'real_name': 'Eric Myers',
#  'user_id': 'U03UUN8M4RX'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e54'),
#  'real_name': 'Mark Crawford',
#  'user_id': 'U03UUP56MDF'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e55'),
#  'real_name': 'Amy Leon',
#  'user_id': 'U03UUR571A5'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e56'),
#  'real_name': 'Jodi Lyons',
#  'user_id': 'U03UUS0MZCZ'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e57'),
#  'real_name': 'Travis Butler',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e58'),
#  'real_name': 'Patrick Hernandez',
#  'user_id': 'U03UYNR4TS4'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e59'),
#  'real_name': 'Vanessa Norman',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e5a'),
#  'real_name': 'Debra Lawrence',
#  'user_id': 'U03V5Q9N516'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e5b'),
#  'real_name': 'Paula Bryant',
#  'user_id': 'U03V61VGQG0'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e5c'),
#  'real_name': 'Cristian Wilson',
#  'user_id': 'U03V6HMRPGQ'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e5d'),
#  'real_name': 'Ashley Hamilton',
#  'user_id': 'U03V785NLSU'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e5e'),
#  'real_name': 'Mandy Sweeney',
#  'user_id': 'U03V8LHPDME'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e5f'),
#  'real_name': 'Paul Brown',
#  'user_id': 'U03VAH809FC'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e60'),
#  'real_name': 'Kathleen Phillips',
#  'user_id': 'U0401GU4W6L'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e61'),
#  'real_name': 'Kenneth Fitzgerald',
#  'user_id': 'U0418T6CD1B'}
# {'_id': ObjectId('656780b6cd32dd8246eb8e62'),
#  'real_name': 'Audrey Parsons',
#  'user_id': 'U04718Y7SQ0'}

# %%
def get_messages_dict(msgs):
    msg_list = {
            "msg_id":[],
            "text":[],
            "user":[],
            "mentions":[],
            "reactions":[],
            "replies":[],
            "replies_to":[],
            "ts":[],
            }


    for msg in msgs:
        if "subtype" not in msg:
            try:
                msg_list["msg_id"].append(msg["client_msg_id"])
            except:
                msg_list["msg_id"].append(None)
            msg_list["text"].append(msg["text"])

            msg_list["user"].append(msg["user"])
            msg_list["ts"].append(msg["ts"])

            
            if "reactions" in msg:
                msg_list["reactions"].append(msg["reactions"])
            else:

                msg_list["reactions"].append(None)

            if "parent_user_id" in msg:
                msg_list["replies_to"].append(msg["ts"])
            else:
                msg_list["replies_to"].append(None)

            if "thread_ts" in msg and "reply_users" in msg:
                msg_list["replies"].append(msg["replies"])
            else:
                msg_list["replies"].append(None)
            
            if "blocks" in msg:
                mention_list = []
                
                for blk in msg["blocks"]:
                    if "elements" in blk:
                        for elm in blk["elements"]:
                            if "elements" in elm:
                                for elm_ in elm["elements"]:
                                    
                                    if "type" in elm_:
                                      
                                        if elm_["type"] == "user":
                                            mention_list.append(elm_["user_id"])
                                       


                msg_list["mentions"].append(mention_list)
            else:
                msg_list["mentions"].append(None)
    
    return msg_list

# %%
def get_messages_from_channel(channel_path):
    '''
    get all the messages from a channel        
    
    '''
    json_files = [
        f"{channel_path}/{pos_json}" 
        for pos_json in os.listdir(channel_path) 
        if pos_json.endswith('.json')
    ]    
    combined = []

    for json_file in json_files:
        with open(json_file, 'r', encoding="utf8") as slack_data:
            json_content = json.load(slack_data)
            combined.extend(json_content)
        
    msg_list = get_messages_dict(combined)
    df = pd.DataFrame(msg_list)
    
    return df

# %% [markdown]
# ## Insert all channels into the mongo database

# %%
all_channels = []
for channel in data_loader.channels:
    cur_channel = {"channel_id": channel["id"], "name": channel["name"]}
    all_channels.append(cur_channel)
    
print("total channels: ", len(all_channels))
print(all_channels[:10])
# Out:
# total channels:  39
# [{'channel_id': 'C03T0APHX63', 'name': 'all-community-building'}, {'channel_id': 'C03T0AX4K6K', 'name': 'all-technical-support'}, {'channel_id': 'C03T89KDGA2', 'name': 'all-career-exercises'}, {'channel_id': 'C03T89PMJKG', 'name': 'all-resources'}, {'channel_id': 'C03TBUCU4UD', 'name': 'random'}, {'channel_id': 'C03TEQM38HH', 'name': 'all-ideas'}, {'channel_id': 'C03TEQQS9NF', 'name': 'all-week1'}, {'channel_id': 'C03U4J8J4LQ', 'name': 'all-broadcast'}, {'channel_id': 'C03UG4LHM8A', 'name': 'tenx-bot'}, {'channel_id': 'C03V3LK61QX', 'name': 'team-10'}]

# %%
inserted_channels = db.insert_many_to_collection('channels', all_channels)
print(inserted_channels)
# Out:
# [ObjectId('656780b8cd32dd8246eb8e63'), ObjectId('656780b8cd32dd8246eb8e64'), ObjectId('656780b8cd32dd8246eb8e65'), ObjectId('656780b8cd32dd8246eb8e66'), ObjectId('656780b8cd32dd8246eb8e67'), ObjectId('656780b8cd32dd8246eb8e68'), ObjectId('656780b8cd32dd8246eb8e69'), ObjectId('656780b8cd32dd8246eb8e6a'), ObjectId('656780b8cd32dd8246eb8e6b'), ObjectId('656780b8cd32dd8246eb8e6c'), ObjectId('656780b8cd32dd8246eb8e6d'), ObjectId('656780b8cd32dd8246eb8e6e'), ObjectId('656780b8cd32dd8246eb8e6f'), ObjectId('656780b8cd32dd8246eb8e70'), ObjectId('656780b8cd32dd8246eb8e71'), ObjectId('656780b8cd32dd8246eb8e72'), ObjectId('656780b8cd32dd8246eb8e73'), ObjectId('656780b8cd32dd8246eb8e74'), ObjectId('656780b8cd32dd8246eb8e75'), ObjectId('656780b8cd32dd8246eb8e76'), ObjectId('656780b8cd32dd8246eb8e77'), ObjectId('656780b8cd32dd8246eb8e78'), ObjectId('656780b8cd32dd8246eb8e79'), ObjectId('656780b8cd32dd8246eb8e7a'), ObjectId('656780b8cd32dd8246eb8e7b'), ObjectId('656780b8cd32dd8246eb8e7c'), ObjectId('656780b8cd32dd8246eb8e7d'), ObjectId('656780b8cd32dd8246eb8e7e'), ObjectId('656780b8cd32dd8246eb8e7f'), ObjectId('656780b8cd32dd8246eb8e80'), ObjectId('656780b8cd32dd8246eb8e81'), ObjectId('656780b8cd32dd8246eb8e82'), ObjectId('656780b8cd32dd8246eb8e83'), ObjectId('656780b8cd32dd8246eb8e84'), ObjectId('656780b8cd32dd8246eb8e85'), ObjectId('656780b8cd32dd8246eb8e86'), ObjectId('656780b8cd32dd8246eb8e87'), ObjectId('656780b8cd32dd8246eb8e88'), ObjectId('656780b8cd32dd8246eb8e89')]

# %%
records = db.find_all('channels')
for record in records:
    pprint.pprint(record)
# Out:
# {'_id': ObjectId('65676695309ab36f1dbec872'),
#  'channel_id': 'C03T0APHX63',
#  'name': 'all-community-building'}
# {'_id': ObjectId('
),
#  'channel_id': 'C03V3LK61QX',
#  'name': 'team-10'}
# {'_id': ObjectId('6567805fcd32dd8246eb4401'),
#  'channel_id': 'C03V9GFAVUN',
#  'name': 'all-week2'}
# {'_id': ObjectId('6567805fcd32dd8246eb4402'),
#  'channel_id': 'C03VBHT7NFQ',
#  'name': 'week2-group'}
# {'_id': ObjectId('6567805fcd32dd8246eb4403'),
#  'channel_id': 'C04042V2P5G',
#  'name': 'ab_test-group'}
# {'_id': ObjectId('6567805fcd32dd8246eb4404'),
#  'channel_id': 'C040TQN9PAL',
#  'name': 'week-2-group-8'}
# {'_id': ObjectId('6567805fcd32dd8246eb4405'),
#  'channel_id': 'C040WBXL341',
#  'name': 'dsa-sql'}
# {'_id': ObjectId('6567805fcd32dd8246eb4406'),
#  'channel_id': 'C0412KS4FGC',
#  'name': 'all-week3'}
# {'_id': ObjectId('6567805fcd32dd8246eb4407'),
#  'channel_id': 'C041JSCLYA3',
#  'name': 'week4-teamwork'}
# {'_id': ObjectId('6567805fcd32dd8246eb4408'),
#  'channel_id': 'C041T15FX9U',
#  'name': 'study-group'}
# {'_id': ObjectId('6567805fcd32dd8246eb4409'),
#  'channel_id': 'C041Z5A7C6P',
#  'name': 'happy-new-year-study-group'}
# {'_id': ObjectId('6567805fcd32dd8246eb440a'),
#  'channel_id': 'C042LQMVBUY',
#  'name': 'all-week4'}
# {'_id': ObjectId('6567805fcd32dd8246eb440b'),
#  'channel_id': 'C042RHJ9W3A',
#  'name': 'batch6_week4_studygroup'}
# {'_id': ObjectId('6567805fcd32dd8246eb440c'),
#  'channel_id': 'C042YEFQFBN',
#  'name': 'all-week5'}
# {'_id': ObjectId('6567805fcd32dd8246eb440d'),
#  'channel_id': 'C044HA7UXS4',
#  'name': 'all-week6'}
# {'_id': ObjectId('6567805fcd32dd8246eb440e'),
#  'channel_id': 'C044VAU85V2',
#  'name': 'all-week7'}
# {'_id': ObjectId('6567805fcd32dd8246eb440f'),
#  'channel_id': 'C04595M5XT3',
#  'name': 'kafka_de'}
# {'_id': ObjectId('6567805fcd32dd8246eb4410'),
#  'channel_id': 'C045BE99895',
#  'name': 'all-week8'}
# {'_id': ObjectId('6567805fcd32dd8246eb4411'),
#  'channel_id': 'C047EE54HPS',
#  'name': 'all-week9'}
# {'_id': ObjectId('6567805fcd32dd8246eb4412'),
#  'channel_id': 'C047UFJ5NSY',
#  'name': 'all-week10'}
# {'_id': ObjectId('6567805fcd32dd8246eb4413'),
#  'channel_id': 'C048T5UP6Q2',
#  'name': 'week-11-group4'}
# {'_id': ObjectId('6567805fcd32dd8246eb4414'),
#  'channel_id': 'C048W5U2F25',
#  'name': 'gokada-challenge-presentation'}
# {'_id': ObjectId('6567805fcd32dd8246eb4415'),
#  'channel_id': 'C049E22FZS4',
#  'name': 'all-week11'}
# {'_id': ObjectId('6567805fcd32dd8246eb4416'),
#  'channel_id': 'C049GV7JK4Y',
#  'name': 'adludios-challange'}
# {'_id': ObjectId('6567805fcd32dd8246eb4417'),
#  'channel_id': 'C049K0LFRU0',
#  'name': 'chang-w11'}
# {'_id': ObjectId('6567805fcd32dd8246eb4418'),
#  'channel_id': 'C049REFEVB9',
#  'name': 'all-ml-week12'}
# {'_id': ObjectId('6567805fcd32dd8246eb4419'),
#  'channel_id': 'C049RETDA31',
#  'name': 'all-de-week12'}
# {'_id': ObjectId('6567805fcd32dd8246eb441a'),
#  'channel_id': 'C04A3FV2L1F',
#  'name': 'all-week12'}
# {'_id': ObjectId('6567805fcd32dd8246eb441b'),
#  'channel_id': 'C04AJMGPU01',
#  'name': 'all-web3-week12'}
# {'_id': ObjectId('6567805fcd32dd8246eb441c'),
#  'channel_id': 'C04BFKFETA9',
#  'name': 'machine-learning'}
# {'_id': ObjectId('6567805fcd32dd8246eb441d'),
#  'channel_id': 'C04BM2JS9DJ',
#  'name': 'data-engineering'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e63'),
#  'channel_id': 'C03T0APHX63',
#  'name': 'all-community-building'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e64'),
#  'channel_id': 'C03T0AX4K6K',
#  'name': 'all-technical-support'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e65'),
#  'channel_id': 'C03T89KDGA2',
#  'name': 'all-career-exercises'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e66'),
#  'channel_id': 'C03T89PMJKG',
#  'name': 'all-resources'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e67'),
#  'channel_id': 'C03TBUCU4UD',
#  'name': 'random'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e68'),
#  'channel_id': 'C03TEQM38HH',
#  'name': 'all-ideas'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e69'),
#  'channel_id': 'C03TEQQS9NF',
#  'name': 'all-week1'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e6a'),
#  'channel_id': 'C03U4J8J4LQ',
#  'name': 'all-broadcast'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e6b'),
#  'channel_id': 'C03UG4LHM8A',
#  'name': 'tenx-bot'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e6c'),
#  'channel_id': 'C03V3LK61QX',
#  'name': 'team-10'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e6d'),
#  'channel_id': 'C03V9GFAVUN',
#  'name': 'all-week2'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e6e'),
#  'channel_id': 'C03VBHT7NFQ',
#  'name': 'week2-group'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e6f'),
#  'channel_id': 'C04042V2P5G',
#  'name': 'ab_test-group'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e70'),
#  'channel_id': 'C040TQN9PAL',
#  'name': 'week-2-group-8'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e71'),
#  'channel_id': 'C040WBXL341',
#  'name': 'dsa-sql'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e72'),
#  'channel_id': 'C0412KS4FGC',
#  'name': 'all-week3'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e73'),
#  'channel_id': 'C041JSCLYA3',
#  'name': 'week4-teamwork'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e74'),
#  'channel_id': 'C041T15FX9U',
#  'name': 'study-group'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e75'),
#  'channel_id': 'C041Z5A7C6P',
#  'name': 'happy-new-year-study-group'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e76'),
#  'channel_id': 'C042LQMVBUY',
#  'name': 'all-week4'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e77'),
#  'channel_id': 'C042RHJ9W3A',
#  'name': 'batch6_week4_studygroup'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e78'),
#  'channel_id': 'C042YEFQFBN',
#  'name': 'all-week5'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e79'),
#  'channel_id': 'C044HA7UXS4',
#  'name': 'all-week6'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e7a'),
#  'channel_id': 'C044VAU85V2',
#  'name': 'all-week7'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e7b'),
#  'channel_id': 'C04595M5XT3',
#  'name': 'kafka_de'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e7c'),
#  'channel_id': 'C045BE99895',
#  'name': 'all-week8'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e7d'),
#  'channel_id': 'C047EE54HPS',
#  'name': 'all-week9'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e7e'),
#  'channel_id': 'C047UFJ5NSY',
#  'name': 'all-week10'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e7f'),
#  'channel_id': 'C048T5UP6Q2',
#  'name': 'week-11-group4'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e80'),
#  'channel_id': 'C048W5U2F25',
#  'name': 'gokada-challenge-presentation'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e81'),
#  'channel_id': 'C049E22FZS4',
#  'name': 'all-week11'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e82'),
#  'channel_id': 'C049GV7JK4Y',
#  'name': 'adludios-challange'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e83'),
#  'channel_id': 'C049K0LFRU0',
#  'name': 'chang-w11'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e84'),
#  'channel_id': 'C049REFEVB9',
#  'name': 'all-ml-week12'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e85'),
#  'channel_id': 'C049RETDA31',
#  'name': 'all-de-week12'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e86'),
#  'channel_id': 'C04A3FV2L1F',
#  'name': 'all-week12'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e87'),
#  'channel_id': 'C04AJMGPU01',
#  'name': 'all-web3-week12'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e88'),
#  'channel_id': 'C04BFKFETA9',
#  'name': 'machine-learning'}
# {'_id': ObjectId('656780b8cd32dd8246eb8e89'),
#  'channel_id': 'C04BM2JS9DJ',
#  'name': 'data-engineering'}

# %% [markdown]
# ## Insert all messages into the mongo database

# %%
import uuid

all_messages = []
for channel in  data_loader.channels:

    channel_messages = get_messages_from_channel(f"../data/{channel["name"]}")


    formatted_messages = channel_messages.apply(lambda msg: {
        "msg_id": msg["msg_id"] if msg["msg_id"] else str(uuid.uuid4()),
        "text": msg["text"],
        "user_id": msg["user"],
        "mentions": msg["mentions"] if msg["mentions"] else [],
        "reactions": msg["reactions"] if msg["reactions"] else [],
        "replies": msg["replies"] if msg["replies"] else [],
        "ts": msg["ts"],
        "channel_id": channel["id"]
    }, axis=1)

    all_messages.extend(formatted_messages.to_list())

# %%
print("total messages: ", len(all_messages))
print(all_messages[:3])
# Out:
# total messages:  18944
# [{'msg_id': '16f68d4e-0ceb-448a-b660-d5ef2eb05305', 'text': '*HOTSEAT ANNOUNCEMENT*', 'user_id': 'U03V1AM5TFA', 'mentions': [], 'reactions': [], 'replies': [], 'ts': '1662620680.298449', 'channel_id': 'C03T0APHX63'}, {'msg_id': '7c641275-2e52-4074-9894-744f049d5377', 'text': "*<!here>* Good morning Community! We are very happy and excited to announce that today's hot seat will be hosting our very own <@U03U1GHT39V>  :wink::clap::skin-tone-2::confetti_ball:   Let's prep our burning questions for him!", 'user_id': 'U03V1AM5TFA', 'mentions': ['U03U1GHT39V'], 'reactions': [{'name': 'fire', 'users': ['U03U9FWPNCE'], 'count': 1}], 'replies': [], 'ts': '1662620806.359419', 'channel_id': 'C03T0APHX63'}, {'msg_id': '245ecc4d-2c1b-4bee-b280-a1fd5ab7fee3', 'text': '*<!here> Community Building Session REMINDER!*:timer_clock:\n*Please note that CBS is on in the next 10min*\n• *Session:* Scavenger hunt\n• *Time*: From 12:00 PM - 12:30 PM UTC\n• *Platform: Gmeet &amp; Slack*\n', 'user_id': 'U03V1AM5TFA', 'mentions': [], 'reactions': [{'name': 'heart_eyes', 'users': ['U03UG4Q7V42', 'U03UFV7HFNF', 'U03UG5VFN03'], 'count': 3}], 'replies': [], 'ts': '1662637801.047169', 'channel_id': 'C03T0APHX63'}]

# %%
def remove_duplicates(json_list, key):
    seen = set()
    unique_list = []

    for item in json_list:
        item_key = item.get(key)
        if item_key not in seen:
            unique_list.append(item)
            seen.add(item_key)

    return unique_list


# Remove duplicates based on 'msg_id'
unique_json_list = remove_duplicates(all_messages, key="msg_id")

# %%
for i in range(len(unique_json_list)):
    db.insert_to_collection("messages", unique_json_list[i])

# %%
records = db.find_all('messages')

# Print the first 5 records
for i, record in enumerate(records):
    if i < 5:
        pprint.pprint(record)
    else:
        break
# Out:
# {'_id': ObjectId('65676f5e309ab36f1dbf5e56'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': '16f68d4e-0ceb-448a-b660-d5ef2eb05305',
#  'reactions': None,
#  'replies': None,
#  'text': '*HOTSEAT ANNOUNCEMENT*',
#  'ts': '1662620680.298449',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676f5e309ab36f1dbf5e57'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': ['U03U1GHT39V'],
#  'msg_id': '7c641275-2e52-4074-9894-744f049d5377',
#  'reactions': [{'count': 1, 'name': 'fire', 'users': ['U03U9FWPNCE']}],
#  'replies': None,
#  'text': '*<!here>* Good morning Community! We are very happy and excited to '
#          "announce that today's hot seat will be hosting our very own "
#          "<@U03U1GHT39V>  :wink::clap::skin-tone-2::confetti_ball:   Let's "
#          'prep our burning questions for him!',
#  'ts': '1662620806.359419',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676f5e309ab36f1dbf5e58'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': '245ecc4d-2c1b-4bee-b280-a1fd5ab7fee3',
#  'reactions': [{'count': 3,
#                 'name': 'heart_eyes',
#                 'users': ['U03UG4Q7V42', 'U03UFV7HFNF', 'U03UG5VFN03']}],
#  'replies': None,
#  'text': '*<!here> Community Building Session REMINDER!*:timer_clock:\n'
#          '*Please note that CBS is on in the next 10min*\n'
#          '• *Session:* Scavenger hunt\n'
#          '• *Time*: From 12:00 PM - 12:30 PM UTC\n'
#          '• *Platform: Gmeet &amp; Slack*\n',
#  'ts': '1662637801.047169',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676f5e309ab36f1dbf5e59'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': 'fe80aff2-20f2-42ad-94a8-8b48ac63083f',
#  'reactions': None,
#  'replies': None,
#  'text': 'Sweet music on Google meet now\n'
#          ':point_right: '
#          '<http://meet.google.com/ysb-kjdn-hpp|meet.google.com/ysb-kjdn-hpp>\n'
#          ':sparkles:JOIN',
#  'ts': '1662638240.075389',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('65676f5e309ab36f1dbf5e5a'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': '2be29318-9c50-4b56-ae0b-ae8bcd4c92a3',
#  'reactions': None,
#  'replies': None,
#  'text': 'Hellooo Helllo again my people the lovely  community:100:, are you '
#          'guys here. …….*Its CBS time*, are we ready today. Show your '
#          'excitement level, mine is :clinking_glasses::dart:',
#  'ts': '1662638402.302519',
#  'user_id': 'U03V1AM5TFA'}
